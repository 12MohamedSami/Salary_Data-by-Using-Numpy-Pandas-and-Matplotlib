# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv("Salary.csv")
df
# Out:
#        Age  Gender  Education Level              Job Title  \
# 0     32.0    Male                1      Software Engineer
# 1     28.0  Female                2           Data Analyst
# 2     45.0    Male                3                Manager
# 3     36.0  Female                1        Sales Associate
# 4     52.0    Male                2               Director
# ...    ...     ...              ...                    ...
# 6679  49.0  Female                3  Director of Marketing
# 6680  32.0    Male                0        Sales Associate
# 6681  30.0  Female                1      Financial Manager
# 6682  46.0    Male                2      Marketing Manager
# 6683  26.0  Female                0        Sales Executive
#
#       Years of Experience    Salary    Country        Race  Senior
# 0                     5.0   90000.0         UK       White       0
# 1                     3.0   65000.0        USA    Hispanic       0
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6684 entries, 0 to 6683
# Data columns (total 9 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   Age                  6684 non-null   float64
#  1   Gender               6684 non-null   object
#  2   Education Level      6684 non-null   int64
#  3   Job Title            6684 non-null   object
#  4   Years of Experience  6684 non-null   float64
#  5   Salary               6684 non-null   float64
#  6   Country              6684 non-null   object
#  7   Race                 6684 non-null   object
#  8   Senior               6684 non-null   int64
# dtypes: float64(3), int64(2), object(4)
# memory usage: 470.1+ KB

# %%
df.describe()
# Out:
#                Age  Education Level  Years of Experience         Salary  \
# count  6684.000000      6684.000000          6684.000000    6684.000000
# mean     33.610563         1.622382             8.077723  115307.175194
# std       7.595994         0.880474             6.029305   52806.810881
# min      21.000000         0.000000             0.000000     350.000000
# 25%      28.000000         1.000000             3.000000   70000.000000
# 50%      32.000000         1.000000             7.000000  115000.000000
# 75%      38.000000         2.000000            12.000000  160000.000000
# max      62.000000         3.000000            34.000000  250000.000000
#
#             Senior
# count  6684.000000
# mean      0.143477
# std       0.350585
# min       0.000000
# 25%       0.000000
# 50%       0.000000
# 75%       0.000000
# max       1.000000

# %%
df.isnull().sum()
# Out:
# Age                    0
# Gender                 0
# Education Level        0
# Job Title              0
# Years of Experience    0
# Salary                 0
# Country                0
# Race                   0
# Senior                 0
# dtype: int64

# %%
df.columns
# Out:
# Index(['Age', 'Gender', 'Education Level', 'Job Title', 'Years of Experience',
#        'Salary', 'Country', 'Race', 'Senior'],
#       dtype='object')

# %%
df["Job Title"].unique()
# Out:
# array(['Software Engineer', 'Data Analyst', 'Manager', 'Sales Associate',
#        'Director', 'Marketing Analyst', 'Product Manager',
#        'Sales Manager', 'Marketing Coordinator', 'Scientist',
#        'Software Developer', 'HR Manager', 'Financial Analyst',
#        'Project Manager', 'Customer Service Rep', 'Operations Manager',
#        'Marketing Manager', 'Engineer', 'Data Entry Clerk',
#        'Sales Director', 'Business Analyst', 'VP of Operations',
#        'IT Support', 'Recruiter', 'Financial Manager',
#        'Social Media Specialist', 'Software Manager', 'Developer',
#        'Consultant', 'Product Designer', 'CEO', 'Accountant',
#        'Data Scientist', 'Marketing Specialist', 'Technical Writer',
#        'HR Generalist', 'Project Engineer', 'Customer Success Rep',
#        'Sales Executive', 'UX Designer', 'Operations Director',
#        'Network Engineer', 'Administrative Assistant',
#        'Strategy Consultant', 'Copywriter', 'Account Manager',
# ...

# %%
df["Job Title"].nunique()
# Out:
# 129

# %%
df.drop_duplicates(subset = ["Job Title"]).sort_values("Gender")
# Out:
#        Age  Gender  Education Level                 Job Title  \
# 78    48.0  Female                2  Human Resources Director
# 58    30.0  Female                1      Social Media Manager
# 56    27.0  Female                2             UX Researcher
# 54    29.0  Female                1          Graphic Designer
# 52    40.0  Female                1         Event Coordinator
# ...    ...     ...              ...                       ...
# 49    25.0    Male                1         Help Desk Analyst
# 46    32.0    Male                1           Account Manager
# 44    41.0    Male                2       Strategy Consultant
# 41    48.0    Male                2       Operations Director
# 5626  24.0    Male                0           Delivery Driver
#
#       Years of Experience    Salary    Country   Race  Senior
# 78                   20.0  180000.0     Canada  Black       0
# 58                    4.0   55000.0     Canada  White       0
# ...

# %%
df['Country'].unique()
# Out:
# array(['UK', 'USA', 'Canada', 'China', 'Australia'], dtype=object)

# %%
df[df["Country"].isin(['UK','USA'])]
# Out:
#        Age  Gender  Education Level                  Job Title  \
# 0     32.0    Male                1          Software Engineer
# 1     28.0  Female                2               Data Analyst
# 3     36.0  Female                1            Sales Associate
# 4     52.0    Male                2                   Director
# 5     29.0    Male                1          Marketing Analyst
# ...    ...     ...              ...                        ...
# 6666  32.0    Male                0       Sales Representative
# 6667  30.0  Female                1              Sales Manager
# 6669  26.0  Female                0            Sales Associate
# 6677  51.0  Female                2  Product Marketing Manager
# 6679  49.0  Female                3      Director of Marketing
#
#       Years of Experience    Salary Country      Race  Senior
# 0                     5.0   90000.0      UK     White       0
# 1                     3.0   65000.0     USA  Hispanic       0
# ...

# %%
Mean_Salary_Of_Each_Country = df.groupby('Country')["Salary"].mean().sort_values()
Mean_Salary_Of_Each_Country
# Out:
# Country
# USA          112998.758112
# Australia    114925.465169
# UK           115919.916667
# China        116282.589993
# Canada       116455.090772
# Name: Salary, dtype: float64

# %%
Mean_Salary_Of_Each_Country.index
# Out:
# Index(['USA', 'Australia', 'UK', 'China', 'Canada'], dtype='object', name='Country')

# %%
plt.bar(Mean_Salary_Of_Each_Country.index , Mean_Salary_Of_Each_Country , color = ['whitesmoke' , 'silver' , 'darkgray' , 'gray', 'dimgray'] )
plt.title("Mean_Salary_Of_Each_Country")
plt.xlabel("Country")
plt.ylabel("Salary")
# Out:
# Text(0, 0.5, 'Salary')

# %%
Max_Salary_Of_Each_Country = df.groupby('Country')["Salary"].max().sort_values()
Max_Salary_Of_Each_Country
# Out:
# Country
# Australia    225000.0
# China        240000.0
# UK           240000.0
# USA          240000.0
# Canada       250000.0
# Name: Salary, dtype: float64

# %%
Max_Salary_Of_Each_Country.index
# Out:
# Index(['Australia', 'China', 'UK', 'USA', 'Canada'], dtype='object', name='Country')

# %%
plt.bar(Max_Salary_Of_Each_Country.index , Max_Salary_Of_Each_Country , color = ['lightcoral' , 'firebrick' , 'firebrick' , 'firebrick', 'maroon'] )
plt.title("Max_Salary_Of_Each_Country")
plt.xlabel("Country")
plt.ylabel("Salary")
# Out:
# Text(0, 0.5, 'Salary')

# %%
Min_Salary_Of_Each_Country = df.groupby('Country')["Salary"].min().sort_values()
Min_Salary_Of_Each_Country
# Out:
# Country
# USA            350.0
# UK             550.0
# Australia    25000.0
# Canada       25000.0
# China        25000.0
# Name: Salary, dtype: float64

# %%
Min_Salary_Of_Each_Country.index
# Out:
# Index(['USA', 'UK', 'Australia', 'Canada', 'China'], dtype='object', name='Country')

# %%
plt.bar(Min_Salary_Of_Each_Country.index , Min_Salary_Of_Each_Country , color = ['royalblue' , 'mediumblue' , 'navy' , 'navy', 'navy'] )
plt.title("Min_Salary_Of_Each_Country")
plt.xlabel("Country")
plt.ylabel("Salary")
# Out:
# Text(0, 0.5, 'Salary')

# %%
df['Race'].unique()
# Out:
# array(['White', 'Hispanic', 'Asian', 'Korean', 'Chinese', 'Australian',
#        'Welsh', 'African American', 'Mixed', 'Black'], dtype=object)

# %%
df['Race'].value_counts()
# Out:
# Race
# White               1957
# Asian               1599
# Korean               457
# Australian           452
# Chinese              443
# Black                435
# African American     352
# Mixed                334
# Welsh                333
# Hispanic             322
# Name: count, dtype: int64

# %%
Race_Gender = df.groupby(['Country' ,'Race'])['Salary'].mean()
Race_Gender
# Out:
# Country    Race
# Australia  Asian               114408.016807
#            Australian          114236.676991
#            White               116295.582310
# Canada     Asian               115159.859341
#            Black               118415.627586
#            White               115845.129630
# China      Chinese             111248.316027
#            Korean              117099.757112
#            White               120512.061503
# UK         Asian               118520.495495
#            Mixed               116330.859281
#            Welsh               112560.645646
#            White               116267.475904
# USA        African American    112355.284091
#            Asian               113298.970149
#            Hispanic            110410.139752
#            White               115763.792507
# Name: Salary, dtype: float64

# %%
Race_Gender.plot(kind="bar")
# Out:
# <Axes: xlabel='Country,Race'>

# %%
No_Of_Gender = df["Gender"].value_counts()
No_Of_Gender
# Out:
# Gender
# Male      3671
# Female    3013
# Name: count, dtype: int64

# %%
plt.pie(No_Of_Gender , labels = {"Female","Male"}, autopct='%1.2f%%',wedgeprops={'edgecolor':'black'})
plt.title('Number of Gender')
plt.show()

# %%
len(df[df["Job Title"]=='Data Analyst'])
# Out:
# 391

# %%
df[df["Job Title"]=='Data Analyst']
# Out:
#        Age  Gender  Education Level     Job Title  Years of Experience  \
# 1     28.0  Female                2  Data Analyst                  3.0
# 81    41.0  Female                2  Data Analyst                 13.0
# 138   36.0    Male                1  Data Analyst                  7.0
# 196   45.0    Male                3  Data Analyst                 17.0
# 242   46.0    Male                3  Data Analyst                 19.0
# ...    ...     ...              ...           ...                  ...
# 4814  28.0    Male                1  Data Analyst                  3.0
# 4824  28.0    Male                1  Data Analyst                  3.0
# 4834  28.0    Male                1  Data Analyst                  3.0
# 4844  28.0    Male                1  Data Analyst                  3.0
# 4854  28.0    Male                1  Data Analyst                  3.0
#
#         Salary    Country      Race  Senior
# 1      65000.0        USA  Hispanic       0
# ...

# %%
df[(df["Job Title"]=='Data Analyst') & (df["Gender"]=="Female")]["Salary"].sum()
# Out:
# 14830000.0

# %%
df[(df["Job Title"]=='Data Analyst') & (df["Gender"]=="Male")]["Salary"].sum()
# Out:
# 32327000.0

# %%
df[df["Job Title"]=="Data Analyst"].sort_values(by= "Salary", ascending = False)["Gender"].reset_index()
# Out:
#      index Gender
# 0      702   Male
# 1      852   Male
# 2      666   Male
# 3      532   Male
# 4      556   Male
# ..     ...    ...
# 386   4663   Male
# 387   4653   Male
# 388   4643   Male
# 389   4633   Male
# 390   4733   Male
#
# [391 rows x 2 columns]

# %%
df_sorted = df.sort_values(by= "Salary", ascending = False)
Unique_jobs = df_sorted.drop_duplicates(subset = "Job Title")
top_10_Jobs = Unique_jobs.head(10)
top_10_Jobs.reset_index()
# Out:
#    index   Age  Gender  Education Level                  Job Title  \
# 0   4983  45.0    Male                1          Financial Manager
# 1     83  52.0    Male                3   Chief Technology Officer
# 2     30  50.0    Male                1                        CEO
# 3   4258  51.0    Male                3             Data Scientist
# 4   4379  49.0    Male                2          Marketing Manager
# 5   2257  46.0  Female                3   Director of Data Science
# 6    105  44.0    Male                3         Chief Data Officer
# 7   1767  55.0    Male                3  Software Engineer Manager
# 8   2202  49.0  Female                3           Project Engineer
# 9   6651  49.0  Female                3      Director of Marketing
#
#    Years of Experience    Salary    Country              Race  Senior
# 0                 21.0  250000.0     Canada             Black       0
# 1                 24.0  250000.0     Canada             Black       0
# ...

# %%
least_sorted = df.sort_values(by= "Salary", ascending = True)
unique_jobs = least_sorted.drop_duplicates(subset = 'Job Title')
least_10_Jobs = unique_jobs.head(10)
least_10_Jobs.reset_index()
# Out:
#    index   Age  Gender  Education Level                        Job Title  \
# 0    258  29.0    Male                1      Business Operations Analyst
# 1   4615  31.0  Female                1                   HR Coordinator
# 2   1888  25.0  Female                1              Front end Developer
# 3   2640  23.0    Male                3        Software Engineer Manager
# 4   4488  30.0  Female                0                  Sales Associate
# 5   5575  24.0  Female                0                     Receptionist
# 6   4944  21.0  Female                0             Sales Representative
# 7   5886  24.0    Male                0                  Delivery Driver
# 8   6316  24.0    Male                3        Digital Marketing Manager
# 9   6006  25.0  Female                0  Customer Service Representative
#
#    Years of Experience   Salary    Country        Race  Senior
# 0                  1.5    350.0        USA    Hispanic       0
# ...

# %%
plt.scatter(  df['Years of Experience'] , df['Salary'] , alpha = 0.5 ,linewidth = 2 )
cbar = plt.colorbar()
cbar.set_label(df['Education Level'])

# %%
                                             #####
                                             #####
                                             ####
                                                       USA INFO 
                                                                         #####
                                                                         #####  
                                                                         ####

# %%
df_USA = df.loc[df['Country']=="USA"].reset_index()
df_USA
# Out:
#       index   Age  Gender  Education Level              Job Title  \
# 0         1  28.0  Female                2           Data Analyst
# 1         3  36.0  Female                1        Sales Associate
# 2         4  52.0    Male                2               Director
# 3         5  29.0    Male                1      Marketing Analyst
# 4         6  42.0  Female                2        Product Manager
# ...     ...   ...     ...              ...                    ...
# 1351   6641  26.0  Female                0        Sales Associate
# 1352   6642  42.0    Male                1      Financial Manager
# 1353   6643  36.0  Female                3      Marketing Manager
# 1354   6661  33.0  Female                1  Director of Marketing
# 1355   6669  26.0  Female                0        Sales Associate
#
#       Years of Experience    Salary Country              Race  Senior
# 0                     3.0   65000.0     USA          Hispanic       0
# ...

# %%
df[(df["Gender"]=="Female")& (df["Country"]=="USA")].reset_index()
# Out:
#      index   Age  Gender  Education Level              Job Title  \
# 0        1  28.0  Female                2           Data Analyst
# 1        3  36.0  Female                1        Sales Associate
# 2        6  42.0  Female                2        Product Manager
# 3       13  40.0  Female                2        Project Manager
# 4       16  33.0  Female                2      Marketing Manager
# ..     ...   ...     ...              ...                    ...
# 612   6615  36.0  Female                3      Marketing Manager
# 613   6641  26.0  Female                0        Sales Associate
# 614   6643  36.0  Female                3      Marketing Manager
# 615   6661  33.0  Female                1  Director of Marketing
# 616   6669  26.0  Female                0        Sales Associate
#
#      Years of Experience    Salary Country              Race  Senior
# 0                    3.0   65000.0     USA          Hispanic       0
# ...

# %%
df[(df["Gender"]=="Male")& (df["Country"]=="USA")].reset_index()
# Out:
#      index   Age Gender  Education Level                  Job Title  \
# 0        4  52.0   Male                2                   Director
# 1        5  29.0   Male                1          Marketing Analyst
# 2       24  41.0   Male                2          Financial Manager
# 3       32  29.0   Male                2             Data Scientist
# 4       34  46.0   Male                3                    Manager
# ..     ...   ...    ...              ...                        ...
# 734   6614  42.0   Male                1          Financial Manager
# 735   6618  27.0   Male                0  Digital Marketing Manager
# 736   6634  28.0   Male                3          Marketing Manager
# 737   6638  32.0   Male                0       Sales Representative
# 738   6642  42.0   Male                1          Financial Manager
#
#      Years of Experience    Salary Country              Race  Senior
# 0                   20.0  200000.0     USA             Asian       0
# ...

# %%
gender_USA = df_USA["Gender"].value_counts()
gender_USA
# Out:
# Gender
# Male      739
# Female    617
# Name: count, dtype: int64

# %%
plt.pie(gender_USA , labels = {'Female','Male'}, autopct='%1.2f%%',wedgeprops={'edgecolor':'black'})
plt.title('Gender')
plt.show()

# %%
df_USA["Salary"].mean()
# Out:
# 112998.7581120944

# %%
df_USA["Salary"].max()
# Out:
# 240000.0

# %%
df_USA["Salary"].min()
# Out:
# 350.0

# %%
df_sorted_USA = df_USA.sort_values(by= "Salary", ascending = False)
Unique_jobs_USA = df_sorted_USA.drop_duplicates(subset="Job Title")
top_10Jobs_USA = Unique_jobs_USA.head(10)
top_10Jobs_USA
# Out:
#       index   Age  Gender  Education Level                  Job Title  \
# 890    4318  51.0    Male                3             Data Scientist
# 444    2257  46.0  Female                3   Director of Data Science
# 22      105  44.0    Male                3         Chief Data Officer
# 1264   6139  40.0  Female                1          Financial Manager
# 334    1729  55.0    Male                3  Software Engineer Manager
# 432    2202  49.0  Female                3           Project Engineer
# 906    4409  45.0    Male                2          Marketing Manager
# 2         4  52.0    Male                2                   Director
# 143     741  33.0  Female                2            Product Manager
# 188     950  42.0  Female                1          Software Engineer
#
#       Years of Experience    Salary Country              Race  Senior
# 890                  24.0  240000.0     USA             White       0
# ...

# %%
df_sorted_USA = df_USA.sort_values(by= "Salary", ascending = True)
Unique_jobs_USA = df_sorted_USA.drop_duplicates(subset="Job Title")
least_10Jobs_USA = Unique_jobs_USA.head(10)
least_10Jobs_USA
# Out:
#       index   Age  Gender  Education Level                        Job Title  \
# 60      258  29.0    Male                1      Business Operations Analyst
# 943    4615  31.0  Female                1                   HR Coordinator
# 1145   5547  24.0  Female                0                     Receptionist
# 785    3875  22.0    Male                0                  Sales Associate
# 1006   4879  21.0  Female                0             Sales Representative
# 1190   5751  25.0  Female                0  Customer Service Representative
# 697    3384  24.0  Female                0                    HR Generalist
# 11       49  25.0    Male                1                Help Desk Analyst
# 749    3680  25.0  Female                1               Software Developer
# 37      153  26.0    Male                1      Customer Support Specialist
#
#       Years of Experience   Salary Country              Race  Senior
# ...

# %%
df_USA['Job Title'].nunique()
# Out:
# 72

# %%
USA_Race = df_USA["Race"].unique()
USA_Race
# Out:
# array(['Hispanic', 'Asian', 'African American', 'White'], dtype=object)

# %%
df_USA['Race'].value_counts()
# Out:
# Race
# African American    352
# White               347
# Asian               335
# Hispanic            322
# Name: count, dtype: int64

# %%
plt.pie(df_USA['Race'].value_counts() , labels = {'African American','White','Asian','Hispanic'}, autopct='%1.2f%%',wedgeprops={'edgecolor':'black'})
plt.title('Race')
plt.show()

# %%
GenderByRace_USA = df_USA.groupby(['Gender','Race'])["Salary"].mean().reset_index()
GenderByRace_USA
# Out:
#    Gender              Race         Salary
# 0  Female  African American  103568.139073
# 1  Female             Asian  104991.940120
# 2  Female          Hispanic  104509.158273
# 3  Female             White  106757.962500
# 4    Male  African American  118956.572139
# 5    Male             Asian  121556.553571
# 6    Male          Hispanic  114892.306011
# 7    Male             White  123469.315508

# %%
GenderByRace_USA.plot(kind="bar")
# Out:
# <Axes: >

# %%
df_USA.groupby(['Years of Experience','Education Level'])["Salary"].mean().reset_index()
# Out:
#     Years of Experience  Education Level         Salary
# 0                   0.0                0   26901.454545
# 1                   0.0                1   43915.500000
# 2                   0.0                2   55538.000000
# 3                   0.0                3   52612.000000
# 4                   0.5                1   35000.000000
# ..                  ...              ...            ...
# 86                 28.0                2  191239.000000
# 87                 28.0                3  182013.000000
# 88                 29.0                3  190543.000000
# 89                 30.0                3  183138.000000
# 90                 32.0                3  191388.500000
#
# [91 rows x 3 columns]

# %%
df_USA.groupby(['Age'])["Salary"].sum().reset_index()
# Out:
#      Age      Salary
# 0   21.0    100000.0
# 1   22.0    166832.0
# 2   23.0    994148.0
# 3   24.0   2062144.0
# 4   25.0   3801000.0
# 5   26.0   5084942.0
# 6   27.0   8375705.0
# 7   28.0   6711989.0
# 8   29.0   8964077.0
# 9   30.0  10030359.0
# 10  31.0   8171499.0
# 11  32.0   9610546.0
# 12  33.0  11623919.0
# 13  34.0   8057646.0
# 14  35.0   4783278.0
# 15  36.0   7118601.0
# 16  37.0   4003000.0
# 17  38.0   4612354.0
# 18  39.0   3468213.0
# 19  40.0   2936372.0
# 20  41.0   3963323.0
# 21  42.0   5901536.0
# 22  43.0   4501132.0
# 23  44.0   4516104.0
# 24  45.0   3692739.0
# 25  46.0   3642552.0
# 26  47.0   1100000.0
# 27  48.0   3629103.0
# 28  49.0   3437113.0
# 29  50.0   1730206.0
# 30  51.0    790000.0
# 31  52.0   1425718.0
# 32  54.0   2651481.0
# 33  55.0    983681.0
# 34  56.0    195000.0
# 35  58.0    190004.0
# 36  61.0    200000.0

# %%
                                             #####
                                             #####
                                             ####
                                                       UK INFO 
                                                                         #####
                                                                         #####  
                                                                         ####

# %%
df_UK = df[df["Country"]=="UK"].reset_index()
df_UK
# Out:
#       index   Age  Gender  Education Level                  Job Title  \
# 0         0  32.0    Male                1          Software Engineer
# 1        10  29.0    Male                2         Software Developer
# 2        11  48.0  Female                1                 HR Manager
# 3        17  39.0    Male                3                   Engineer
# 4        18  25.0  Female                1           Data Entry Clerk
# ...     ...   ...     ...              ...                        ...
# 1327   6663  51.0  Female                2  Content Marketing Manager
# 1328   6666  32.0    Male                0       Sales Representative
# 1329   6667  30.0  Female                1              Sales Manager
# 1330   6677  51.0  Female                2  Product Marketing Manager
# 1331   6679  49.0  Female                3      Director of Marketing
#
#       Years of Experience    Salary Country   Race  Senior
# 0                     5.0   90000.0      UK  White       0
# ...

# %%
df[(df["Gender"]=="Female")& (df["Country"]=="UK")].reset_index()
# Out:
#      index   Age  Gender  Education Level                  Job Title  \
# 0       11  48.0  Female                1                 HR Manager
# 1       18  25.0  Female                1           Data Entry Clerk
# 2       31  31.0  Female                1                 Accountant
# 3       36  35.0  Female                1              HR Generalist
# 4       40  34.0  Female                2                UX Designer
# ..     ...   ...     ...              ...                        ...
# 604   6649  51.0  Female                2  Product Marketing Manager
# 605   6663  51.0  Female                2  Content Marketing Manager
# 606   6667  30.0  Female                1              Sales Manager
# 607   6677  51.0  Female                2  Product Marketing Manager
# 608   6679  49.0  Female                3      Director of Marketing
#
#      Years of Experience    Salary Country   Race  Senior
# 0                   18.0  140000.0      UK  Asian       0
# ...

# %%
df[(df["Gender"]=="Male")& (df["Country"]=="UK")].reset_index()
# Out:
#      index   Age Gender  Education Level                  Job Title  \
# 0        0  32.0   Male                1          Software Engineer
# 1       10  29.0   Male                2         Software Developer
# 2       17  39.0   Male                3                   Engineer
# 3       21  47.0   Male                2           VP of Operations
# 4       22  30.0   Male                1                 IT Support
# ..     ...   ...    ...              ...                        ...
# 718   6652  32.0   Male                0            Sales Associate
# 719   6656  42.0   Male                1  Content Marketing Manager
# 720   6658  24.0   Male                1       Sales Representative
# 721   6660  27.0   Male                0              Sales Manager
# 722   6666  32.0   Male                0       Sales Representative
#
#      Years of Experience    Salary Country   Race  Senior
# 0                    5.0   90000.0      UK  White       0
# ...

# %%
gender_UK = df_UK["Gender"].value_counts()
gender_UK
# Out:
# Gender
# Male      723
# Female    609
# Name: count, dtype: int64

# %%
plt.pie(gender_UK , labels = {'Female','Male'}, autopct='%1.2f%%',wedgeprops={'edgecolor':'black'})
plt.title('Gender')
plt.show()

# %%
df_UK["Salary"].mean()
# Out:
# 115919.91666666667

# %%
df_UK["Salary"].max()
# Out:
# 240000.0

# %%
df_UK["Salary"].min()
# Out:
# 550.0

# %%
df_sorted_UK = df_UK.sort_values(by= "Salary", ascending = False)
Unique_jobs_UK = df_sorted_UK.drop_duplicates(subset="Job Title")
top_10Jobs_UK = Unique_jobs_UK.head(10)
top_10Jobs_UK
# Out:
#       index   Age  Gender  Education Level                  Job Title  \
# 842    4273  51.0    Male                3             Data Scientist
# 1213   6085  40.0  Female                1          Financial Manager
# 331    1672  55.0    Male                3  Software Engineer Manager
# 643    3249  48.0    Male                3   Director of Data Science
# 869    4399  45.0    Male                2          Marketing Manager
# 405    2038  50.0    Male                3           Project Engineer
# 1331   6679  49.0  Female                3      Director of Marketing
# 1320   6637  49.0  Female                3  Product Marketing Manager
# 138     713  33.0  Female                2            Product Manager
# 572    2923  54.0    Male                2          Software Engineer
#
#       Years of Experience    Salary Country   Race  Senior
# 842                  24.0  240000.0      UK  Welsh       0
# 1213                 16.0  215000.0      UK  White       0
# ...

# %%
df_sorted_UK = df_UK.sort_values(by= "Salary", ascending = True)
Unique_jobs_UK = df_sorted_UK.drop_duplicates(subset="Job Title")
least_10Jobs_UK = Unique_jobs_UK.head(10)
least_10Jobs_UK
# Out:
#       index   Age  Gender  Education Level                        Job Title  \
# 374    1888  25.0  Female                1              Front end Developer
# 522    2640  23.0    Male                3        Software Engineer Manager
# 868    4398  30.0  Female                0                  Sales Associate
# 1007   5119  22.0  Female                0                     Receptionist
# 994    5013  21.0  Female                0             Sales Representative
# 1108   5626  24.0    Male                0                  Delivery Driver
# 1199   6006  25.0  Female                0  Customer Service Representative
# 676    3443  25.0  Female                2                    HR Generalist
# 903    4557  23.0  Female                1                   HR Coordinator
# 1294   6517  25.0  Female                0                  Sales Executive
#
#       Years of Experience   Salary Country   Race  Senior
# 374                   1.0    550.0      UK  Mixed       0
# ...

# %%
df_UK['Job Title'].nunique()
# Out:
# 77

# %%
UK_Race = df_UK["Race"].unique()
UK_Race
# Out:
# array(['White', 'Welsh', 'Asian', 'Mixed'], dtype=object)

# %%
df_UK['Race'].value_counts()
# Out:
# Race
# Mixed    334
# Welsh    333
# Asian    333
# White    332
# Name: count, dtype: int64

# %%
plt.pie(df_UK['Race'].value_counts() , labels = {'Mixed','Welsh ','Asian','White'}, autopct='%1.2f%%',wedgeprops={'edgecolor':'black'})
plt.title('Race')
plt.show()

# %%
RaceByGender_UK = df_UK.groupby(['Gender','Race'])["Salary"].mean().reset_index()
RaceByGender_UK
# Out:
#    Gender   Race         Salary
# 0  Female  Asian  106835.865248
# 1  Female  Mixed  108091.310345
# 2  Female  Welsh  108379.775758
# 3  Female  White  110318.772152
# 4    Male  Asian  127101.395833
# 5    Male  Mixed  122652.206349
# 6    Male  Welsh  116666.857143
# 7    Male  White  121669.172414

# %%
RaceByGender_UK.plot(kind="bar")
# Out:
# <Axes: >

# %%
df_UK.groupby(['Years of Experience','Education Level'])["Salary"].mean().reset_index()
# Out:
#     Years of Experience  Education Level         Salary
# 0                   0.0                0   26864.500000
# 1                   0.0                1   37500.000000
# 2                   0.0                3   52653.750000
# 3                   1.0                0   30076.882353
# 4                   1.0                1   53643.596491
# ..                  ...              ...            ...
# 85                 30.0                1  186321.000000
# 86                 31.0                3  197354.000000
# 87                 32.0                2  195270.000000
# 88                 32.0                3  191510.000000
# 89                 33.0                2  188232.000000
#
# [90 rows x 3 columns]

# %%
df_UK.groupby(['Age'])["Salary"].sum().reset_index()
# Out:
#      Age     Salary
# 0   21.0    25000.0
# 1   22.0   126832.0
# 2   23.0   999480.0
# 3   24.0  2200317.0
# 4   25.0  3669550.0
# 5   26.0  5280709.0
# 6   27.0  7987857.0
# 7   28.0  8540899.0
# 8   29.0  5973000.0
# 9   30.0  8996184.0
# 10  31.0  8207208.0
# 11  32.0  6906916.0
# 12  33.0  9307464.0
# 13  34.0  9015887.0
# 14  35.0  5002086.0
# 15  36.0  7415802.0
# 16  37.0  4328000.0
# 17  38.0  4245630.0
# 18  39.0  6287000.0
# 19  40.0  2095748.0
# 20  41.0  3743727.0
# 21  42.0  5159884.0
# 22  43.0  5147521.0
# 23  44.0  3314577.0
# 24  45.0  6251707.0
# 25  46.0  3958837.0
# 26  47.0  1619985.0
# 27  48.0  3381659.0
# 28  49.0  4295186.0
# 29  50.0  3155886.0
# 30  51.0  1757913.0
# 31  52.0   579588.0
# 32  53.0   180000.0
# 33  54.0  2867197.0
# 34  55.0   804507.0
# 35  56.0   587354.0
# 36  57.0   188232.0
# 37  58.0   200000.0
# 38  61.0   200000.0
# 39  62.0   400000.0

# %%
                                             #####
                                             #####
                                             ####
                                                       CANADA INFO 
                                                                         #####
                                                                         #####  
                                                                         ####

# %%
df_Canada = df[df["Country"]=="Canada"].reset_index()
df_Canada
# Out:
#       index   Age  Gender  Education Level                Job Title  \
# 0         2  45.0    Male                3                  Manager
# 1        14  27.0    Male                1     Customer Service Rep
# 2        25  28.0  Female                1  Social Media Specialist
# 3        28  43.0  Female                3               Consultant
# 4        30  50.0    Male                1                      CEO
# ...     ...   ...     ...              ...                      ...
# 1317   6662  28.0    Male                3        Marketing Manager
# 1318   6672  24.0    Male                1          Sales Executive
# 1319   6673  43.0  Female                2            Sales Manager
# 1320   6678  37.0    Male                1     Sales Representative
# 1321   6683  26.0  Female                0          Sales Executive
#
#       Years of Experience    Salary Country   Race  Senior
# 0                    15.0  150000.0  Canada  White       1
# ...

# %%
df[(df["Gender"]=="Female")& (df["Country"]=="Canada")].reset_index()
# Out:
#      index   Age  Gender  Education Level                  Job Title  \
# 0       25  28.0  Female                1    Social Media Specialist
# 1       28  43.0  Female                3                 Consultant
# 2       33  39.0  Female                1       Marketing Specialist
# 3       38  26.0  Female                1       Customer Success Rep
# 4       54  29.0  Female                1           Graphic Designer
# ..     ...   ...     ...              ...                        ...
# 577   6633  33.0  Female                1      Director of Marketing
# 578   6635  51.0  Female                2  Content Marketing Manager
# 579   6639  30.0  Female                1              Sales Manager
# 580   6673  43.0  Female                2              Sales Manager
# 581   6683  26.0  Female                0            Sales Executive
#
#      Years of Experience    Salary Country   Race  Senior
# 0                    3.0   45000.0  Canada  White       0
# ...

# %%
df[(df["Gender"]=="Male")& (df["Country"]=="Canada")].reset_index()
# Out:
#      index   Age Gender  Education Level              Job Title  \
# 0        2  45.0   Male                3                Manager
# 1       14  27.0   Male                1   Customer Service Rep
# 2       30  50.0   Male                1                    CEO
# 3       41  48.0   Male                2    Operations Director
# 4       59  35.0   Male                2        Product Manager
# ..     ...   ...    ...              ...                    ...
# 735   6632  27.0   Male                0          Sales Manager
# 736   6640  46.0   Male                2  Director of Marketing
# 737   6662  28.0   Male                3      Marketing Manager
# 738   6672  24.0   Male                1        Sales Executive
# 739   6678  37.0   Male                1   Sales Representative
#
#      Years of Experience    Salary Country   Race  Senior
# 0                   15.0  150000.0  Canada  White       1
# 1                    2.0   40000.0  Canada  Asian       0
# ...

# %%
gender_Canada = df_Canada["Gender"].value_counts()
gender_Canada
# Out:
# Gender
# Male      740
# Female    582
# Name: count, dtype: int64

# %%
plt.pie(gender_Canada , labels = {'Female','Male'}, autopct='%1.2f%%',wedgeprops={'edgecolor':'black'})
plt.title('Gender')
plt.show()

# %%
df_Canada["Salary"].mean()
# Out:
# 116455.09077155824

# %%
df_Canada["Salary"].max()
# Out:
# 250000.0

# %%
df_Canada["Salary"].min()
# Out:
# 25000.0

# %%
df_sorted_Canada = df_Canada.sort_values(by= "Salary", ascending = False)
Unique_jobs_Canada = df_sorted_Canada.drop_duplicates(subset="Job Title")
top_10Jobs_Canada = Unique_jobs_Canada.head(10)
top_10Jobs_Canada
# Out:
#       index   Age  Gender  Education Level                  Job Title  \
# 973    4983  45.0    Male                1          Financial Manager
# 4        30  50.0    Male                1                        CEO
# 17       83  52.0    Male                3   Chief Technology Officer
# 835    4258  51.0    Male                3             Data Scientist
# 859    4379  49.0    Male                2          Marketing Manager
# 525    2650  46.0    Male                3   Director of Data Science
# 436    2123  50.0    Male                3           Project Engineer
# 1307   6623  49.0  Female                3      Director of Marketing
# 1306   6609  49.0  Female                3  Product Marketing Manager
# 297    1451  58.0    Male                3  Software Engineer Manager
#
#       Years of Experience    Salary Country   Race  Senior
# 973                  21.0  250000.0  Canada  Black       0
# 4                    25.0  250000.0  Canada  Asian       0
# ...

# %%
df_sorted_Canada = df_Canada.sort_values(by= "Salary", ascending = True)
Unique_jobs_Canada = df_sorted_Canada.drop_duplicates(subset="Job Title")
least_10Jobs_Canada = Unique_jobs_Canada.head(10)
least_10Jobs_Canada
# Out:
#       index   Age  Gender  Education Level                        Job Title  \
# 872    4423  31.0  Female                0                  Sales Associate
# 1200   6069  24.0  Female                0                     Receptionist
# 970    4957  21.0  Female                0             Sales Representative
# 1188   6013  24.0    Male                0                  Delivery Driver
# 1109   5619  25.0  Female                0  Customer Service Representative
# 903    4585  24.0  Female                0           Juniour HR Coordinator
# 696    3500  25.0  Female                2                    HR Generalist
# 714    3597  30.0    Male                0                   HR Coordinator
# 1269   6413  25.0  Female                0                  Sales Executive
# 738    3740  25.0  Female                1               Software Developer
#
#       Years of Experience   Salary Country   Race  Senior
# 872                   1.0  25000.0  Canada  White       0
# ...

# %%
df_Canada['Job Title'].nunique()
# Out:
# 73

# %%
Canada_Race = df_Canada["Race"].unique()
Canada_Race
# Out:
# array(['White', 'Asian', 'Black'], dtype=object)

# %%
df_Canada['Race'].value_counts()
# Out:
# Race
# Asian    455
# Black    435
# White    432
# Name: count, dtype: int64

# %%
plt.pie(df_Canada['Race'].value_counts() , labels = {'Black','Asian','White'}, autopct='%1.2f%%',wedgeprops={'edgecolor':'black'})
plt.title('Race')
plt.show()

# %%
RaceByGender_Canada = df_Canada.groupby(['Gender','Race'])["Salary"].mean().reset_index()
RaceByGender_Canada
# Out:
#    Gender   Race         Salary
# 0  Female  Asian  105812.939394
# 1  Female  Black  108602.208333
# 2  Female  White  106272.479167
# 3    Male  Asian  122360.988327
# 4    Male  Black  126169.440329
# 5    Male  White  123503.250000

# %%
RaceByGender_Canada.plot(kind="bar")
# Out:
# <Axes: >

# %%
df_Canada.groupby(['Years of Experience','Education Level'])["Salary"].mean().reset_index()
# Out:
#     Years of Experience  Education Level         Salary
# 0                   0.0                0   25142.857143
# 1                   0.0                1   46415.500000
# 2                   0.0                3   52779.000000
# 3                   1.0                0   29765.822222
# 4                   1.0                1   54553.191489
# ..                  ...              ...            ...
# 82                 30.0                3  121450.000000
# 83                 31.0                2  193746.000000
# 84                 32.0                2  195270.000000
# 85                 33.0                2  188232.000000
# 86                 34.0                3  188651.000000
#
# [87 rows x 3 columns]

# %%
df_Canada.groupby(['Age'])["Salary"].sum().reset_index()
# Out:
#      Age     Salary
# 0   21.0    25000.0
# 1   22.0    75000.0
# 2   23.0   665610.0
# 3   24.0  2706363.0
# 4   25.0  2848000.0
# 5   26.0  5476388.0
# 6   27.0  8095728.0
# 7   28.0  8976269.0
# 8   29.0  8277474.0
# 9   30.0  9190407.0
# 10  31.0  7094975.0
# 11  32.0  8049311.0
# 12  33.0  9843911.0
# 13  34.0  7854000.0
# 14  35.0  4923523.0
# 15  36.0  7553392.0
# 16  37.0  3981000.0
# 17  38.0  3379592.0
# 18  39.0  3727360.0
# 19  40.0  2145942.0
# 20  41.0  4129000.0
# 21  42.0  4962098.0
# 22  43.0  4843004.0
# 23  44.0  4812203.0
# 24  45.0  6077320.0
# 25  46.0  3081345.0
# 26  47.0  1776300.0
# 27  48.0  5031844.0
# 28  49.0  3541068.0
# 29  50.0  4090376.0
# 30  51.0  1526610.0
# 31  52.0  1201000.0
# 32  53.0   181714.0
# 33  54.0  2137170.0
# 34  55.0   190000.0
# 35  56.0   390000.0
# 36  57.0   309682.0
# 37  58.0   395000.0
# 38  60.0   188651.0
# 39  62.0   200000.0

# %%
                                             #####
                                             #####
                                             ####
                                                       CHINA INFO 
                                                                         #####
                                                                         #####  
                                                                         ####

# %%
df_China = df[df["Country"]=="China"].reset_index()
df_China
# Out:
#       index   Age  Gender  Education Level              Job Title  \
# 0         7  31.0    Male                1          Sales Manager
# 1         8  26.0  Female                1  Marketing Coordinator
# 2        12  35.0    Male                1      Financial Analyst
# 3        15  44.0    Male                1     Operations Manager
# 4        20  34.0  Female                2       Business Analyst
# ...     ...   ...     ...              ...                    ...
# 1334   6668  46.0    Male                2  Director of Marketing
# 1335   6671  36.0  Female                3      Marketing Manager
# 1336   6676  28.0    Male                3   Sales Representative
# 1337   6681  30.0  Female                1      Financial Manager
# 1338   6682  46.0    Male                2      Marketing Manager
#
#       Years of Experience    Salary Country     Race  Senior
# 0                     4.0   80000.0   China   Korean       0
# ...

# %%
df[(df["Gender"]=="Female")& (df["Country"]=="China")].reset_index()
# Out:
#      index   Age  Gender  Education Level                  Job Title  \
# 0        8  26.0  Female                1      Marketing Coordinator
# 1       20  34.0  Female                2           Business Analyst
# 2       23  36.0  Female                1                  Recruiter
# 3       50  51.0  Female                1   Customer Service Manager
# 4       52  40.0  Female                1          Event Coordinator
# ..     ...   ...     ...              ...                        ...
# 586   6655  26.0  Female                0            Sales Executive
# 587   6657  36.0  Female                3  Product Marketing Manager
# 588   6665  49.0  Female                3  Product Marketing Manager
# 589   6671  36.0  Female                3          Marketing Manager
# 590   6681  30.0  Female                1          Financial Manager
#
#      Years of Experience    Salary Country     Race  Senior
# 0                    1.0   45000.0   China  Chinese       0
# ...

# %%
df[(df["Gender"]=="Male")& (df["Country"]=="China")].reset_index()
# Out:
#      index   Age Gender  Education Level              Job Title  \
# 0        7  31.0   Male                1          Sales Manager
# 1       12  35.0   Male                1      Financial Analyst
# 2       15  44.0   Male                1     Operations Manager
# 3       29  33.0   Male                2       Product Designer
# 4       37  42.0   Male                2       Project Engineer
# ..     ...   ...    ...              ...                    ...
# 743   6650  37.0   Male                1   Sales Representative
# 744   6664  37.0   Male                1         Sales Director
# 745   6668  46.0   Male                2  Director of Marketing
# 746   6676  28.0   Male                3   Sales Representative
# 747   6682  46.0   Male                2      Marketing Manager
#
#      Years of Experience    Salary Country     Race  Senior
# 0                    4.0   80000.0   China   Korean       0
# 1                    6.0   65000.0   China   Korean       0
# ...

# %%
gender_China = df_China["Gender"].value_counts()
gender_China
# Out:
# Gender
# Male      748
# Female    591
# Name: count, dtype: int64

# %%
plt.pie(gender_China , labels = {'Female','Male'}, autopct='%1.2f%%',wedgeprops={'edgecolor':'black'})
plt.title('Gender')
plt.show()

# %%
df_China["Salary"].mean()
# Out:
# 116282.58999253174

# %%
df_China["Salary"].max()
# Out:
# 240000.0

# %%
df_China["Salary"].min()
# Out:
# 25000.0

# %%
df_sorted_China = df_China.sort_values(by= "Salary", ascending = False)
Unique_jobs_China = df_sorted_China.drop_duplicates(subset="Job Title")
top_10Jobs_China = Unique_jobs_China.head(10)
top_10Jobs_China
# Out:
#       index   Age  Gender  Education Level                  Job Title  \
# 846    4288  51.0    Male                3             Data Scientist
# 1228   6195  40.0  Female                1          Financial Manager
# 538    2679  48.0    Male                3   Director of Data Science
# 334    1691  55.0    Male                3  Software Engineer Manager
# 414    2142  49.0  Female                3           Project Engineer
# 865    4414  45.0    Male                2          Marketing Manager
# 1333   6665  49.0  Female                3  Product Marketing Manager
# 177     857  33.0  Female                2            Product Manager
# 577    2805  54.0    Male                2          Software Engineer
# 136     646  31.0    Male                1               Data Analyst
#
#       Years of Experience    Salary Country     Race  Senior
# 846                  24.0  240000.0   China   Korean       0
# 1228                 16.0  215000.0   China    White       0
# ...

# %%
df_sorted_China = df_China.sort_values(by= "Salary", ascending = True)
Unique_jobs_China = df_sorted_China.drop_duplicates(subset="Job Title")
least_10Jobs_China = Unique_jobs_China.head(10)
least_10Jobs_China
# Out:
#       index   Age  Gender  Education Level                       Job Title  \
# 1218   6151  24.0  Female                0                    Receptionist
# 798    4013  28.0  Female                0                 Sales Associate
# 1016   5104  21.0  Female                0            Sales Representative
# 695    3524  27.0  Female                0                  HR Coordinator
# 1258   6316  24.0    Male                3       Digital Marketing Manager
# 691    3503  24.0  Female                0                   HR Generalist
# 890    4519  25.0  Female                0          Juniour HR Coordinator
# 752    3790  26.0  Female                1              Software Developer
# 1240   6244  23.0  Female                0                 Sales Executive
# 32      165  27.0    Male                1  Business Development Associate
#
#       Years of Experience   Salary Country     Race  Senior
# 1218                  0.0  25000.0   China   Korean       0
# ...

# %%
df_China['Job Title'].nunique()
# Out:
# 63

# %%
China_Race = df_China["Race"].unique()
China_Race
# Out:
# array(['Korean', 'Chinese', 'White'], dtype=object)

# %%
df_China['Race'].value_counts()
# Out:
# Race
# Korean     457
# Chinese    443
# White      439
# Name: count, dtype: int64

# %%
plt.pie(df_China['Race'].value_counts() , labels = {'Korean','Chinese','White'}, autopct='%1.2f%%',wedgeprops={'edgecolor':'black'})
plt.title('Race')
plt.show()

# %%
RaceByGender_China = df_China.groupby(['Gender','Race'])["Salary"].mean().reset_index()
RaceByGender_China
# Out:
#    Gender     Race         Salary
# 0  Female  Chinese  106422.709184
# 1  Female   Korean  110948.144186
# 2  Female    White  117002.244444
# 3    Male  Chinese  115077.542510
# 4    Male   Korean  122565.033058
# 5    Male    White  122951.316602

# %%
RaceByGender_China.plot(kind="bar")
# Out:
# <Axes: >

# %%
df_China.groupby(['Years of Experience','Education Level'])["Salary"].mean().reset_index()
# Out:
#     Years of Experience  Education Level         Salary
# 0                   0.0                0   25000.000000
# 1                   0.0                1   46415.500000
# 2                   0.0                3   52779.000000
# 3                   1.0                0   29800.000000
# 4                   1.0                1   57807.328767
# ..                  ...              ...            ...
# 86                 30.0                1  183020.000000
# 87                 32.0                2  195270.000000
# 88                 32.0                3  191510.000000
# 89                 33.0                3  187586.666667
# 90                 34.0                3  188651.000000
#
# [91 rows x 3 columns]

# %%
df_China.groupby(['Age'])["Salary"].sum().reset_index()
# Out:
#      Age      Salary
# 0   21.0    150000.0
# 1   22.0     50000.0
# 2   23.0   1159610.0
# 3   24.0   2609117.0
# 4   25.0   3712816.0
# 5   26.0   4588231.0
# 6   27.0   7441968.0
# 7   28.0   5698508.0
# 8   29.0   6515149.0
# 9   30.0   9214188.0
# 10  31.0   9301017.0
# 11  32.0   8005354.0
# 12  33.0  10246491.0
# 13  34.0   9193567.0
# 14  35.0   5266421.0
# 15  36.0   8586015.0
# 16  37.0   5799434.0
# 17  38.0   3960046.0
# 18  39.0   4658455.0
# 19  40.0   3748032.0
# 20  41.0   3720662.0
# 21  42.0   5634771.0
# 22  43.0   5460413.0
# 23  44.0   3226454.0
# 24  45.0   4031532.0
# 25  46.0   4104353.0
# 26  47.0   1699985.0
# 27  48.0   3196062.0
# 28  49.0   3067053.0
# 29  50.0   2765180.0
# 30  51.0   1376159.0
# 31  52.0   1679905.0
# 32  53.0    181714.0
# 33  54.0   1928748.0
# 34  55.0   1003563.0
# 35  56.0    795000.0
# 36  57.0    773580.0
# 37  58.0    585004.0
# 38  60.0    367831.0
# 39  62.0    200000.0

# %%
                                             #####
                                             #####
                                             ####
                                                       AUSTRALIA INFO 
                                                                         #####
                                                                         #####  
                                                                         ####

# %%
df_Australia = df[df["Country"]=="Australia"].reset_index()
df_Australia
# Out:
#       index   Age  Gender  Education Level                  Job Title  \
# 0         9  38.0    Male                3                  Scientist
# 1        19  51.0    Male                1             Sales Director
# 2        26  37.0  Female                2           Software Manager
# 3        27  24.0    Male                1                  Developer
# 4        35  27.0    Male                1           Technical Writer
# ...     ...   ...     ...              ...                        ...
# 1330   6659  43.0  Female                2  Digital Marketing Manager
# 1331   6670  42.0    Male                1          Financial Manager
# 1332   6674  27.0    Male                0  Digital Marketing Manager
# 1333   6675  33.0  Female                1  Content Marketing Manager
# 1334   6680  32.0    Male                0            Sales Associate
#
#       Years of Experience    Salary    Country        Race  Senior
# ...

# %%
df[(df["Gender"]=="Female")& (df["Country"]=="Australia")].reset_index()
# Out:
#      index   Age  Gender  Education Level                  Job Title  \
# 0       26  37.0  Female                2           Software Manager
# 1       79  30.0  Female                1  Content Marketing Manager
# 2       84  29.0  Female                1                   Designer
# 3       89  31.0  Female                1      Marketing Coordinator
# 4      100  31.0  Female                1          Event Coordinator
# ..     ...   ...     ...              ...                        ...
# 609   6621  51.0  Female                2  Product Marketing Manager
# 610   6645  43.0  Female                2              Sales Manager
# 611   6651  49.0  Female                3      Director of Marketing
# 612   6659  43.0  Female                2  Digital Marketing Manager
# 613   6675  33.0  Female                1  Content Marketing Manager
#
#      Years of Experience    Salary    Country        Race  Senior
# 0                   11.0  110000.0  Australia       Asian       0
# ...

# %%
df[(df["Gender"]=="Female")& (df["Country"]=="Australia")].reset_index()
# Out:
#      index   Age  Gender  Education Level                  Job Title  \
# 0       26  37.0  Female                2           Software Manager
# 1       79  30.0  Female                1  Content Marketing Manager
# 2       84  29.0  Female                1                   Designer
# 3       89  31.0  Female                1      Marketing Coordinator
# 4      100  31.0  Female                1          Event Coordinator
# ..     ...   ...     ...              ...                        ...
# 609   6621  51.0  Female                2  Product Marketing Manager
# 610   6645  43.0  Female                2              Sales Manager
# 611   6651  49.0  Female                3      Director of Marketing
# 612   6659  43.0  Female                2  Digital Marketing Manager
# 613   6675  33.0  Female                1  Content Marketing Manager
#
#      Years of Experience    Salary    Country        Race  Senior
# 0                   11.0  110000.0  Australia       Asian       0
# ...

# %%
gender_Aust = df_Australia['Gender'].value_counts()
gender_Aust
# Out:
# Gender
# Male      721
# Female    614
# Name: count, dtype: int64

# %%
plt.pie(gender_Aust , labels = {'Female','Male'}, autopct='%1.2f%%',wedgeprops={'edgecolor':'black'})
plt.title('Gender')
plt.show()

# %%
df_Australia["Salary"].mean()
# Out:
# 114925.46516853933

# %%
df_Australia["Salary"].max()
# Out:
# 225000.0

# %%
df_Australia["Salary"].min()
# Out:
# 25000.0

# %%
df_sorted_Australia = df_Australia.sort_values(by= "Salary", ascending = False)
Unique_jobs_Australia = df_sorted_Australia.drop_duplicates(subset="Job Title")
top_10Jobs_Australia = Unique_jobs_Australia.head(10)
top_10Jobs_Australia
# Out:
#       index   Age  Gender  Education Level                  Job Title  \
# 861    4224  50.0    Male                3             Data Scientist
# 1225   6153  40.0  Female                1          Financial Manager
# 635    3190  48.0    Male                3   Director of Data Science
# 458    2191  50.0    Male                3  Software Engineer Manager
# 902    4444  45.0    Male                2          Marketing Manager
# 436    2106  50.0    Male                3           Project Engineer
# 1328   6651  49.0  Female                3      Director of Marketing
# 8        53  47.0    Male                2              VP of Finance
# 116     561  33.0  Female                2            Product Manager
# 171     842  31.0    Male                1               Data Analyst
#
#       Years of Experience    Salary    Country        Race  Senior
# 861                  23.0  225000.0  Australia       White       0
# ...

# %%
df_sorted_Australia = df_Australia.sort_values(by= "Salary", ascending = True)
Unique_jobs_Australia = df_sorted_Australia.drop_duplicates(subset="Job Title")
least_10Jobs_Australia = Unique_jobs_Australia.head(10)
least_10Jobs_Australia
# Out:
#       index   Age  Gender  Education Level             Job Title  \
# 818    4043  28.0  Female                0       Sales Associate
# 1243   6235  24.0  Female                0          Receptionist
# 998    4944  21.0  Female                0  Sales Representative
# 1220   6123  24.0    Male                0       Delivery Driver
# 679    3405  27.0  Female                0        HR Coordinator
# 920    4537  26.0  Female                1         HR Generalist
# 766    3805  26.0  Female                1    Software Developer
# 1326   6644  24.0    Male                1       Sales Executive
# 9        64  26.0    Male                1            Accountant
# 1284   6450  23.0    Male                1         Sales Manager
#
#       Years of Experience   Salary    Country        Race  Senior
# 818                   1.0  25000.0  Australia       Asian       0
# 1243                  0.0  25000.0  Australia       Asian       0
# ...

# %%
df_Australia['Job Title'].nunique()
# Out:
# 69

# %%
Australia_Race = df_Australia["Race"].unique()
Australia_Race
# Out:
# array(['Australian', 'Asian', 'White'], dtype=object)

# %%
df_Australia['Race'].value_counts()
# Out:
# Race
# Asian         476
# Australian    452
# White         407
# Name: count, dtype: int64

# %%
plt.pie(df_Australia['Race'].value_counts() , labels = {'Asian ','Australian','White'}, autopct='%1.2f%%',wedgeprops={'edgecolor':'black'})
plt.title('Race')
plt.show()

# %%
RaceByGender_Aust = df_Australia.groupby(['Gender','Race'])["Salary"].mean().reset_index()
RaceByGender_Aust
# Out:
#    Gender        Race         Salary
# 0  Female       Asian  107715.561905
# 1  Female  Australian  108245.014354
# 2  Female       White  107771.553846
# 3    Male       Asian  119691.533835
# 4    Male  Australian  119390.000000
# 5    Male       White  124136.080189

# %%
RaceByGender_Aust.plot(kind="bar")
# Out:
# <Axes: >

# %%
df_Australia.groupby(['Years of Experience','Education Level'])["Salary"].mean().reset_index()
# Out:
#     Years of Experience  Education Level         Salary
# 0                   0.0                0   25391.304348
# 1                   0.0                1   40610.333333
# 2                   0.0                3   52779.000000
# 3                   1.0                0   30434.317073
# 4                   1.0                1   51935.460526
# ..                  ...              ...            ...
# 80                 28.0                2  189140.250000
# 81                 30.0                3  153055.000000
# 82                 31.0                3  191818.000000
# 83                 32.0                3  191267.000000
# 84                 33.0                3  179180.000000
#
# [85 rows x 3 columns]

# %%
df_Australia.groupby(['Age'])["Salary"].sum().reset_index()
# Out:
#      Age     Salary
# 0   21.0   150000.0
# 1   22.0    75000.0
# 2   23.0   963417.0
# 3   24.0  2674599.0
# 4   25.0  3930000.0
# 5   26.0  5487729.0
# 6   27.0  8031463.0
# 7   28.0  6168553.0
# 8   29.0  8349849.0
# 9   30.0  7874738.0
# 10  31.0  8651899.0
# 11  32.0  9723436.0
# 12  33.0  9693471.0
# 13  34.0  6687075.0
# 14  35.0  3897859.0
# 15  36.0  7000345.0
# 16  37.0  4488336.0
# 17  38.0  4392028.0
# 18  39.0  5129641.0
# 19  40.0  2861301.0
# 20  41.0  4468676.0
# 21  42.0  5789347.0
# 22  43.0  6182615.0
# 23  44.0  4356040.0
# 24  45.0  4474840.0
# 25  46.0  2679634.0
# 26  47.0  2204985.0
# 27  48.0  3648269.0
# 28  49.0  2859816.0
# 29  50.0  5053143.0
# 30  51.0   560000.0
# 31  52.0   555041.0
# 32  53.0   390000.0
# 33  54.0  2687757.0
# 34  55.0   193964.0
# 35  56.0   195000.0
# 36  57.0   321450.0
# 37  60.0   374180.0
# 38  62.0   200000.0
